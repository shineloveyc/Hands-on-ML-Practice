# %%
#get absolute working directory name
import os
os.getcwd()
# Out:
# 'C:\\Users\\syao\\OneDrive - ATC Tires Pvt. Ltd\\Python Project'

# %%
#laod the package
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,silhouette_samples
import matplotlib.cm as cm
import matplotlib as mpl
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
##renders plot inline on your page. 
# %matplotlib inline

# %%
sales = pd.ExcelFile('C:/Users/syao/OneDrive - ATC Tires Pvt. Ltd/Python Project/Data/Final Sales database 2014 to 2018.xlsx')

# %%
#set global option to display all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
sales_db = sales.parse('Sheet1')

# %% [markdown]
# #sales = pd.read_excel(r'C:\Users\syao\OneDrive - ATC Tires Pvt. Ltd\Python Project\Data\Final Sales database 2014 to 2018.xlsx') r will convert the normal string to a raw string

# %%
sales_db.head(6)
# Out:
#                              Customer     Group Invoice No. Posting Date  \
# 0     8196 - WINGFOOT COMMERCIAL TIRE  WINGFOOT    SI173893   2014-07-23
# 1         70000 - DEL-NAT CORPORATION       NaN    SI168098   2014-05-22
# 2  8756 - MALONE WAREHOUSE TIRE, INC.       NaN    SI163425   2014-04-03
# 3   601175 - CENTRAL TIRE SERVICE INC       NaN    SI159336   2014-02-14
# 4   601175 - CENTRAL TIRE SERVICE INC       NaN    CR107005   2014-02-26
# 5   601175 - CENTRAL TIRE SERVICE INC       NaN    CR107005   2014-02-26
#
#    Year Order No./Pre-Assigned No.   Item No.  Parent          Size  \
# 0  2014                   SO250461  135271-77  135271  33X1550-16.5
# 1  2014                   SO236308  135271-77  135271  33X1550-16.5
# 2  2014                   SO230913  135271-77  135271  33X1550-16.5
# 3  2014                   SO223246  135271-77  135271  33X1550-16.5
# 4  2014                   SC103435  135271-77  135271  33X1550-16.5
# 5  2014                   SC103435  135271-77  135271  33X1550-16.5
#
#                     Description  Quantity                 Description.1  \
# 0  GALAXY MIGHTY MOW R3 10PR TL       4.0  GALAXY MIGHTY MOW R3 10PR TL
# 1  GALAXY MIGHTY MOW R3 10PR TL       1.0  GALAXY MIGHTY MOW R3 10PR TL
# 2  GALAXY MIGHTY MOW R3 10PR TL       1.0  GALAXY MIGHTY MOW R3 10PR TL
# 3  GALAXY MIGHTY MOW R3 10PR TL       2.0  GALAXY MIGHTY MOW R3 10PR TL
# 4  GALAXY MIGHTY MOW R3 10PR TL      -2.0  GALAXY MIGHTY MOW R3 10PR TL
# 5  GALAXY MIGHTY MOW R3 10PR TL       2.0  GALAXY MIGHTY MOW R3 10PR TL
#
#          Size.1 Location Customer Type Branch Code X Branch (AM/OE)  \
# 0  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 1  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 2  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 3  33X1550-16.5  MEMPHIS           A/M          AM               AM
# 4  33X1550-16.5  MEMPHIS           A/M          AM               AM
# 5  33X1550-16.5  MEMPHIS           A/M          AM               AM
#
#   Ship-to State Code  Territory    Salesperson Ship-to Country Ship-to City  \
# 0                 WI  N Central  Dallas Ransom              US    OAK CREEK
# 1                 TN  Southeast     Blaine Cox              US      MEMPHIS
# 2                 OH  Northeast   Mark Scanlon              US       ATHENS
# 3                 NY  Northeast   Keith Browne              US    BAY SHORE
# 4                 NY  Northeast   Keith Browne              US    BAY SHORE
# 5                 NY  Northeast   Keith Browne              US    BAY SHORE
#
#    X Sales                 Ship-to Name   Brand Category Dashboard Category  \
# 0  1580.00     WINGFOOT COMMERCIAL TIRE  GALAXY      AGR                 LG
# 1   418.16          DEL-NAT CORPORATION  GALAXY      AGR                 LG
# 2   418.16  MALONE WAREHOUSE TIRE, INC.  GALAXY      AGR                 LG
# 3   871.12     CENTRAL TIRE SERVICE INC  GALAXY      AGR                 LG
# 4  -871.12     CENTRAL TIRE SERVICE INC  GALAXY      AGR                 LG
# 5   760.00     CENTRAL TIRE SERVICE INC  GALAXY      AGR                 LG
#
#   Final Category Vendor Source    Channel
# 0             LG        DURO01  WAREHOUSE
# 1             LG        DURO01  WAREHOUSE
# 2             LG        DURO01  WAREHOUSE
# 3             LG        DURO01  WAREHOUSE
# 4             LG        DURO01  WAREHOUSE
# 5             LG        DURO01  WAREHOUSE

# %%
sales_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512019 entries, 0 to 512018
# Data columns (total 30 columns):
# Customer                      512019 non-null object
# Group                         175295 non-null object
# Invoice No.                   512019 non-null object
# Posting Date                  512019 non-null datetime64[ns]
# Year                          512019 non-null int64
# Order No./Pre-Assigned No.    505571 non-null object
# Item No.                      512019 non-null object
# Parent                        512019 non-null object
# Size                          512003 non-null object
# Description                   512005 non-null object
# Quantity                      512016 non-null float64
# Description.1                 512019 non-null object
# Size.1                        512006 non-null object
# Location                      512019 non-null object
# Customer Type                 503106 non-null object
# Branch Code                   512019 non-null object
# X Branch (AM/OE)              512019 non-null object
# Ship-to State Code            511251 non-null object
# Territory                     511197 non-null object
# Salesperson                   511197 non-null object
# Ship-to Country               512019 non-null object
# Ship-to City                  503097 non-null object
# X Sales                       512016 non-null float64
# Ship-to Name                  512018 non-null object
# Brand                         512019 non-null object
# Category                      512019 non-null object
# Dashboard Category            512019 non-null object
# Final Category                512019 non-null object
# Vendor Source                 511791 non-null object
# Channel                       512001 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(26)
# memory usage: 117.2+ MB

# %%
#add ASP column
sales_db['ASP']= sales_db['X Sales'] / sales_db.Quantity

# %%
sales_db.head(4)
# Out:
#                              Customer     Group Invoice No. Posting Date  \
# 0     8196 - WINGFOOT COMMERCIAL TIRE  WINGFOOT    SI173893   2014-07-23
# 1         70000 - DEL-NAT CORPORATION       NaN    SI168098   2014-05-22
# 2  8756 - MALONE WAREHOUSE TIRE, INC.       NaN    SI163425   2014-04-03
# 3   601175 - CENTRAL TIRE SERVICE INC       NaN    SI159336   2014-02-14
#
#    Year Order No./Pre-Assigned No.   Item No.  Parent          Size  \
# 0  2014                   SO250461  135271-77  135271  33X1550-16.5
# 1  2014                   SO236308  135271-77  135271  33X1550-16.5
# 2  2014                   SO230913  135271-77  135271  33X1550-16.5
# 3  2014                   SO223246  135271-77  135271  33X1550-16.5
#
#                     Description  Quantity                 Description.1  \
# 0  GALAXY MIGHTY MOW R3 10PR TL       4.0  GALAXY MIGHTY MOW R3 10PR TL
# 1  GALAXY MIGHTY MOW R3 10PR TL       1.0  GALAXY MIGHTY MOW R3 10PR TL
# 2  GALAXY MIGHTY MOW R3 10PR TL       1.0  GALAXY MIGHTY MOW R3 10PR TL
# 3  GALAXY MIGHTY MOW R3 10PR TL       2.0  GALAXY MIGHTY MOW R3 10PR TL
#
#          Size.1 Location Customer Type Branch Code X Branch (AM/OE)  \
# 0  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 1  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 2  33X1550-16.5  MEMPHIS       A/M-GAP          AM               AM
# 3  33X1550-16.5  MEMPHIS           A/M          AM               AM
#
#   Ship-to State Code  Territory    Salesperson Ship-to Country Ship-to City  \
# 0                 WI  N Central  Dallas Ransom              US    OAK CREEK
# 1                 TN  Southeast     Blaine Cox              US      MEMPHIS
# 2                 OH  Northeast   Mark Scanlon              US       ATHENS
# 3                 NY  Northeast   Keith Browne              US    BAY SHORE
#
#    X Sales                 Ship-to Name   Brand Category Dashboard Category  \
# 0  1580.00     WINGFOOT COMMERCIAL TIRE  GALAXY      AGR                 LG
# 1   418.16          DEL-NAT CORPORATION  GALAXY      AGR                 LG
# 2   418.16  MALONE WAREHOUSE TIRE, INC.  GALAXY      AGR                 LG
# 3   871.12     CENTRAL TIRE SERVICE INC  GALAXY      AGR                 LG
#
#   Final Category Vendor Source    Channel     ASP
# 0             LG        DURO01  WAREHOUSE  395.00
# 1             LG        DURO01  WAREHOUSE  418.16
# 2             LG        DURO01  WAREHOUSE  418.16
# 3             LG        DURO01  WAREHOUSE  435.56

# %%
sales_db_v1 = sales_db.copy().drop(['Size', 'Description','Order No./Pre-Assigned No.'], axis = 1)

# %%
#explort how many dashboard category
sales_db_v1['Final Category'].value_counts()
# Out:
# AGR                152962
# Truck              148796
# SS                  60930
# CU                  58658
# Bias OTR            21318
# FOR                 18497
# Radial OTR          15193
# IND                 12077
# LG                   8486
# Trailer Service      8179
# SOLID                4995
# OTHER                1594
# Other                 334
# Name: Final Category, dtype: int64

# %%
#analyzing sales by category and channel

ax = sales_db_v1.groupby(['Year','Final Category'])['X Sales'].sum().unstack().plot(kind = 'bar',figsize=(12,4) )

ax.get_legend().set_bbox_to_anchor((1.1, 1))

plt.show()

# %% [markdown]
# ## RFM Score Calculating
# R: Recency, days since last purchase
# F: Frequency, total number of purchase
# M: Total money this customer spent

# %%
# filter on US AM sales
sales_us_am = sales_db_v1.loc[(sales_db_v1['Ship-to Country']=="US") & (sales_db_v1['Branch Code']=='AM')]

# %%
#check missing value in each columns
sales_us_am.isnull().sum(axis = 0)
# Out:
# Customer                   0
# Group                 313985
# Invoice No.                0
# Posting Date               0
# Year                       0
# Item No.                   0
# Parent                     0
# Quantity                   0
# Description.1              0
# Size.1                    10
# Location                   0
# Customer Type           8399
# Branch Code                0
# X Branch (AM/OE)           0
# Ship-to State Code       115
# Territory                115
# Salesperson              115
# Ship-to Country            0
# Ship-to City            8388
# X Sales                    0
# Ship-to Name               1
# Brand                      0
# Category                   0
# Dashboard Category         0
# Final Category             0
# Vendor Source            206
# Channel                   18
# ASP                     6771
# dtype: int64

# %%
#check negative value and then remove negative values in Quantity/Sales
sales_us_am['Quantity'].min()

sales_us_am = sales_us_am[(sales_us_am['X Sales']>0)]

# %%
sales_us_am.info()

sales_us_am.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453006 entries, 0 to 512018
# Data columns (total 28 columns):
# Customer              453006 non-null object
# Group                 149124 non-null object
# Invoice No.           453006 non-null object
# Posting Date          453006 non-null datetime64[ns]
# Year                  453006 non-null int64
# Item No.              453006 non-null object
# Parent                453006 non-null object
# Quantity              453006 non-null float64
# Description.1         453006 non-null object
# Size.1                452996 non-null object
# Location              453006 non-null object
# Customer Type         445804 non-null object
# Branch Code           453006 non-null object
# X Branch (AM/OE)      453006 non-null object
# Ship-to State Code    452900 non-null object
# Territory             452900 non-null object
# Salesperson           452900 non-null object
# Ship-to Country       453006 non-null object
# Ship-to City          445841 non-null object
# X Sales               453006 non-null float64
# Ship-to Name          453006 non-null object
# Brand                 453006 non-null object
# Category              453006 non-null object
# Dashboard Category    453006 non-null object
# Final Category        453006 non-null object
# Vendor Source         452805 non-null object
# Channel               453006 non-null object
# ASP                   453006 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(23)
# memory usage: 100.2+ MB
#                 Year       Quantity        X Sales            ASP
# count  453006.000000  453006.000000  453006.000000  453006.000000
# mean     2015.844406       8.436211    2310.297423     432.610951
# std         1.378762      17.713731    3910.776763     553.816270
# min      2014.000000       1.000000       1.000000       0.877143
# 25%      2015.000000       2.000000     515.685000     170.230000
# 50%      2016.000000       4.000000    1144.640000     221.230000
# 75%      2017.000000       8.000000    2500.297500     414.852500
# max      2018.000000     800.000000  167929.980000   54052.000000

# %%
#check last order dates
sales_us_am['Posting Date'].max()
# Out:
# Timestamp('2018-12-31 00:00:00')

# %%
import datetime as dt
#use 2019.1.1 as the point of time to calcuate the recencey
now = dt.datetime(2019,1,1)

# %%
#create RFM table for customer segmation
rfmTable = sales_us_am.groupby('Customer').agg({'Posting Date': lambda x:(now - x.max()).days, 'Invoice No.': lambda x:len(x), 
                                                'X Sales': lambda x: x.sum()})

# %%
rfmTable['Posting Date'] = rfmTable['Posting Date'].astype(int)

# %%
rfmTable.rename(columns = {'Posting Date':'Recency', 'Invoice No.': 'Frequency', 'X Sales':'Monetary_Value'}, inplace = True)

# %%
rfmTable.head(4)
# Out:
#                                    Recency  Frequency  Monetary_Value
# Customer
# 010130 - AAL-STAR TIRE                 757         16        21729.87
# 0101570 - J & O TIRE                   755         57       361554.55
# 01070 - ALLIED OIL & SUPPLY, INC.      888          6        16534.52
# 01074 - REDDING VALLEY TIRE INC        777        101       213172.40

# %%
#split customers by using quartiles
quantiles = rfmTable.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'Recency': {0.25: 161.0, 0.5: 740.0, 0.75: 894.5},
#  'Frequency': {0.25: 3.0, 0.5: 15.0, 0.75: 89.5},
#  'Monetary_Value': {0.25: 6349.085000000001, 0.5: 35241.84, 0.75: 223444.435}}

# %%
#create a segmented RFM table
segmented_rfm = rfmTable

# %%
#function to assign the score, d is dataframe and p is column, x mean apply to which column
def RScore(x,p,d):
    if x<=d[p][0.25]:
        return 1
    elif x<= d[p][0.50]:
        return 2
    elif x<=d[p][0.75]:
        return 3
    else:
        return 4
def FMScore(x, p, d):
    if x<=d[p][0.25]:
        return 4
    elif x<= d[p][0.50]:
        return 3
    elif x<=d[p][0.75]:
        return 2
    else:
        return 1

# %%
#add segment to newly created segmentated RFM table
segmented_rfm['r_quartile'] = segmented_rfm['Recency'].apply(RScore,args = ('Recency', quantiles))

segmented_rfm['f_quartile'] = segmented_rfm['Frequency'].apply(FMScore,args = ('Frequency', quantiles))

segmented_rfm['m_quartile'] = segmented_rfm['Monetary_Value'].apply(FMScore,args = ('Monetary_Value', quantiles))

# %%
segmented_rfm.head(4)
# Out:
#                                    Recency  Frequency  Monetary_Value  \
# Customer
# 010130 - AAL-STAR TIRE                 757         16        21729.87
# 0101570 - J & O TIRE                   755         57       361554.55
# 01070 - ALLIED OIL & SUPPLY, INC.      888          6        16534.52
# 01074 - REDDING VALLEY TIRE INC        777        101       213172.40
#
#                                    r_quartile  f_quartile  m_quartile
# Customer
# 010130 - AAL-STAR TIRE                      3           2           3
# 0101570 - J & O TIRE                        3           2           1
# 01070 - ALLIED OIL & SUPPLY, INC.           3           3           3
# 01074 - REDDING VALLEY TIRE INC             3           1           2

# %%
#add new column to combine thr rfm score, map return a list of result by apply the str function
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str)+segmented_rfm.f_quartile.map(str)+segmented_rfm.m_quartile.map(str)

# %%
#get top 200 customers
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('Monetary_Value', ascending = False)
# Out:
#                                             Recency  Frequency  \
# Customer
# C0001774 - TWIN VALLEY TIRE                       1       3198
# C0000351 - GCR TIRE CENTERS                       1       5977
# C0002311 - DUNLAP & KYLE                          1       4707
# C0009125 - SOUTHERN TIRE MART                     1       4409
# C0001728 - BEN TIRE DISTRIBUTORS                  4       3096
# C0002307 - BLACK'S TIRE SERVICE INC.              4       4436
# C0048753 - POMP'S TIRE SERVICE, INC.              1       3117
# C0002227 - BAUER BUILT TIRE                      14        893
# C0033776 - GALLAGHER TIRE, INC.                   4       3469
# C0008756 - MALONE WAREHOUSE TIRE, INC.            1       1317
# C0051789 - SOUTHEASTERN WHOLESALE TIRE            1       4151
# C0001737 - BALL & PRIER TIRE                      1       1326
# C0001529 - LES SCHWAB                             1       1665
# C0006427 - S&S TIRE (FIRESTONE), INC.             1       3324
# C0003104 - RICE TIRE COMPANY                      4       2428
# C0600606 - MARTINS TIRE & ALIGNMENT CTR           6       2795
# C0004610 - COMMERCIAL FARM INDUST. TIRE           1       1084
# C0001695 - TREADMAXX TIRE DISTRIBUTORS,INC        1       2068
# C0009785 - J.P. THOMAS & CO, INC.                 1       1166
# C0035507 - COMMERCIAL TIRE                       13       2232
# C0009024 - GRAHAM TIRE COMPANY                    4       1244
# C0600079 - JEE TIRE SALES                         4       2419
# C0025602 - CHEYENNE TIRE COMPANY                  1        931
# C0005629 - HARRIS TIRE COMPANY                    4       1770
# C0606479 - TIRE DISTRIBUTORS OF GEORGIA           1       2092
# C0001839 - KANSASLAND TIRE                       14       1321
# C0007814 - STATEWIDE TIRE DISTRIBUTOR INC         5       1701
# C0001508 - EAST BAY TIRE CO.                      1       1080
# C0048547 - RABEN TIRE                             1       1042
# C0065000 - MOORE'S TIRE SALES, INC.               4       2138
# C0009661 - FUTURE TIRE COMPANY, LTD.             14       1019
# C0005683 - WESTSIDE WHOLESALE TIRE INC.           1       1961
# C0606718 - COMMUNITY WHOLESALE TIRE               1       1412
# C0026493 - PURCELL TIRE & RUBBER COMPANY          4       2555
# C0001906 - AG EQUIPMENT SPECIALITIES              5        691
# C0606007 - LOVE'S TRAVEL STOPS & COUNTRY         36        185
# C0047713 - PLAINSMAN TIRE                        15        594
# C0601051 - ZURCHER 'S BEST-ONE TIRE &             5       1298
# C0002313 - HESSELBEIN-JACKSON                     1        983
# C0606876 - TIRE'S WAREHOUSE, INC                 15       1595
# C0173850 - PETE'S ROAD SERVICE, INC.              4       1414
# C0001136 - COMMERCIAL TIRE (Corcoran)             5        945
# C0025600 - INTERCITY TIRE & AUTO CENTER           6        649
# C0043047 - T & W TIRE                             5        831
# C0005500 - CENTRAL TIRE COMPANY, INC.             6       1556
# C0000125 - PHOENIX TIRE Inc.                    104       1035
# C0029004 - F & S TIRE CORP, INC.                  5        274
# C0003705 - K & M TIRE, INC                        1       1599
# C0006957 - COLONY TIRE                            1        280
# C0052063 - STAR TIRE COMPANY, INC.                1        554
# C0041734 - LESLIE TIRE SERVICE                    4        441
# C0009779 - GRAHAM TIRE -SIOUX CITY               22        640
# C0009783 - GRAHAM TIRE - MASON CITY               1        694
# C0700002 - US VENTURE                             5        770
# C0042565 - MONRO MUFFLER BRAKE, INC               1        999
# C0049330 - ROUSE TIRE COMPANY                     5        482
# C0009545 - GRAHAM TIRE COMPANY                   12        586
# C0042536 - MCCARTHY TIRE-CORPORATE                1        424
# C0008214 - DAKOTA WHOLESALE TIRE                 25        274
# C0004160 - BEALL TIRE COMPANY                    14        748
# C0606072 - YOUNGBLOOD AUTOMOTIVE & TIRE           4        738
# C0001351 - FORREST BROTHERS TIRE                 33        474
# C0601220 - McGRIFF TIRE - A/P                     4        450
# C0000804 - CBA TIRE INC/DBA TREDROC TIRE          6        520
# C0001712 - DILLER EQUIPMENT                       5        123
# C0003785 - SOUTHERN INDIANA TIRE                 15        662
# C0009477 - GILBREATH ENTERPRISES, INC.            4        349
# C0036967 - BOBBY HENARD, INC.                    14        363
# C0058790 - KCB INC.                               5        881
# C0009781 - GRAHAM TIRE-MARSHALL                  32        315
# C0006499 - REDCO TIRE, INC.                      14        660
# C0026092 - BEST ONE TIRE OF JACKSON              18        253
# C0001613 - BOULEVARD TIRE CENTER                  1        708
# C0008918 - TRI STATE RUBBER CO.INC.              35        750
# C0041659 - LEETE TIRE & AUTO CENTER              12        286
# C0002395 - BARNWELL HOUSE OF TIRES                5        569
# C0051329 - W.GLENN SEDAM                         12        977
# C0003892 - ROAD-MART, INC.                       11        130
# C0048016 - MCWHORTER'S, LTD.                      1        232
# C0006682 - MOORE LOGGING SUPPLY, INC.             4        149
# C0001953 - CUSTOM BANDAG COMPANY, INC.            1        146
# C0700215 - TBC CORPORATION                        1        210
# C0008157 - ST. LUCIE BATTERY & TIRE              11       1000
# C0600285 - SCHIERL TIRE, INC.                    15        194
# C0003358 - BLUE RIDGE TRUCK TIRE CENTER          25        340
# C0601984 - SOUTHERN SECTION REPAIR INC           15        306
# C0009782 - GRAHAM TIRE-STORM LAKE                12        260
# C0026916 - RELIABLE TIRE                         33        301
# C0605185 - TIRE MERCHANTS INT'L                  18        724
# C0605309 - BACK BAY CAPITAL CORP                  5        309
# C0026544 - OLD DOMINION TIRE DIRECT, INC.        14        412
# C0041960 - DEALERS TIRE SUPPLY                    1        462
# C0004822 - POMP'S TIRE SERVICE, INC              11        467
# C0606237 - MILLERSBURG TIRE SERVICE,INC          67        446
# C0025725 - FARMERS COOPERATIVE                   14        267
# C0600712 - TIM'S TIRES/L & T TIRES LLC            5        338
# C0606111 - PEARSON TIRE-SALT LAKE                11        511
# C0008161 - TIRE RAMA ACCOUNTS PAYABLE DEPT        4        497
# C0002809 - TIRE GROUP INTERNATIONAL INC.         13        316
# C0600114 - TRIUMPH TIRES LLC                     13        291
# C0064850 - FORREST TIRE COMPANY, INC.            19        148
# C0014950 - AMERICAN TIRE                         28        217
# C0009466 - TIREMAXX, INC.                        18        213
# C0003557 - SPARKS COMMERCIAL TIRE                12        480
# C0605204 - ANDY'S SMART TIRES LLC                 1        115
# C0005917 - DAVE STERN TIRES                       6        497
# C0000915 - NW RETREADERS                         15        414
# C0008451 - R.P.M. TRUCK CENTER                   36         90
# C0700106 - TIRES ONLY,INC                        11        144
# C0600100 - MFR TIRE SERVICE, INC.                54        133
# C0605297 - COMMERCIAL FARM & IND.TIRE             1        417
# C0052312 - STATEWIDE TIRE OF ST. LOUIS            6        172
# C0011071 - A B TIRE COMPANY                      14        548
# C0006344 - COWSER TIRE COMPANY                   11        372
# C0006940 - COMMERCIAL TIRE SERVICE               11        278
# C0042435 - MCKNIGHT TIRE COMPANY                 32        302
# C0004296 - CY-FAIR TIRE ROAD SERVICE, LLC        11        328
# C0049199 - ROBBIE TIRE                           22        106
# C0606739 - J.W.BAMFORD                           35        231
# C0048399 - MASSANELLI, INC.                      13        293
# C0039500 - KEN JONES TIRE COMPANY                22        525
# C0044705 - MAINE COMMERCIAL TIRE                 13        314
# C0049957 - OASIS TRUCK TIRE SERVICE, LLC          4        320
# C0601949 - JACK'S OK TIRE SERVICE CO             61        202
# C0048602 - PARRISH TIRE                          25        182
# C0600648 - SONNY JOHNSON TIRE                    27        187
# C0033915 - PITTSBURGH GENERAL TIRE                6        119
# C0600845 - SILVERSTONE, INC.                     18        103
# C0008072 - MAR-BAR TIRE SERVICE                   4        457
# C0601549 - UNIVERSAL TIRE                        55        142
# C0009640 - JIM WHITEHEAD TIRE SERVICE,INC        25        127
# C0001694 - SIMONAR SERVICE                       55        228
# C0009778 - GRAHAM TIRE - SPENCER, IA             32         94
# C0003909 - TIRESOLES OF BROWARD                  29        263
# C0025768 - S & S TIRE COMPANY                    50        181
# C0003483 - PARMENTER, INC.                       32        119
# C0054085 - PETE'S TIRE BARNS, INC                11        225
# C0601083 - MESILLA VALLEY COMM. TIRE INC.        21        151
# C0600811 - GRAHAM TIRE - DES MOINES             127        121
# C0605345 - YOUNG'S DIST.CO.INC                   56        128
# C0009780 - GRAHAM TIRE CO.-FT.DODGE              22        145
# C0028985 - BRUCE'S TIRE                          62        170
# C0600148 - K & S TIRE, INC.                       5         99
# C0006561 - TALLMADGE TIRE SVC OF BING            13        128
# C0605328 - MCKEE EQUIPMENT CO.                   43        211
# C0606508 - CASSIDY TIRE COMPANY                  12        116
# C0600989 - COMMERCIAL & INDUSTRIAL TIRE          20        157
# C0600287 - RUBBER PRODUCTS TIRE COMPANY          18        229
# C0606683 - JAMAR TIRE SERVICE                    15        122
# C0606027 - STALEY'S TIRE & AUTOMOTIVE            43        214
# C0005108 - TIRESOLES/ELPEX-FT. PIERCE            12        143
# C0051334 - STRATHAM TIRE                          5         94
# C0008752 - TIRE OUTLET, INC.                    132        149
# C0029352 - FLEET TIRE SERVICE, INC.              19        167
# C0009022 - GENE'S TIRES INC.                     34        198
# C0008915 - TRIPLE T AUTOMOTIVE, LLC              11        100
# C0009059 - GOOD TIRE                             12        188
# C0008047 - ROADRUNNER TIRE DISTRUBUTORS          33        124
# C0606740 - HARRY VANCE LOGGING                   19        147
# C0025204 - BILLINGSLEY TIRE                       4        133
# C0601770 - ROY'S TIRES, INC                      27        111
# C0009105 - BOB SUMEREL TIRE COMPANY, INC.        13        107
# C0001074 - REDDING VALLEY TIRE INC               19        127
# C0083625 - HEUTON TIRE COMPANY                   19        155
# C0700082 - VALLEY TIRE SALES                      4        259
# C0045412 - D & J TIRE INC                         1         97
# C0050754 - HERMAN POWER TIRE SVC., INC.          14        107
# C0007974 - BINGHAMTON TRUCK & TIRE CENTER        19        127
# C0600734 - CROSS DILLON TIRE, INC.               12         93
# C0606823 - DISCOUNT TRUCK TIRES, LLC             95        150
# C0009612 - HIGHWAY TIRE, INC.                    43        136
#
#                                             Monetary_Value  r_quartile  \
# Customer
# C0001774 - TWIN VALLEY TIRE                    17791691.20           1
# C0000351 - GCR TIRE CENTERS                    17630134.30           1
# C0002311 - DUNLAP & KYLE                       15706500.32           1
# C0009125 - SOUTHERN TIRE MART                  15145871.96           1
# C0001728 - BEN TIRE DISTRIBUTORS               11342905.63           1
# C0002307 - BLACK'S TIRE SERVICE INC.            8224976.22           1
# C0048753 - POMP'S TIRE SERVICE, INC.            8155273.48           1
# C0002227 - BAUER BUILT TIRE                     8005363.46           1
# C0033776 - GALLAGHER TIRE, INC.                 7783386.20           1
# C0008756 - MALONE WAREHOUSE TIRE, INC.          7073493.67           1
# C0051789 - SOUTHEASTERN WHOLESALE TIRE          6780852.29           1
# C0001737 - BALL & PRIER TIRE                    6119448.63           1
# C0001529 - LES SCHWAB                           6076044.62           1
# C0006427 - S&S TIRE (FIRESTONE), INC.           5962472.81           1
# C0003104 - RICE TIRE COMPANY                    5774321.79           1
# C0600606 - MARTINS TIRE & ALIGNMENT CTR         5352808.71           1
# C0600989 - COMMERCIAL & INDUSTRIAL TIRE              1           1      111
# C0600287 - RUBBER PRODUCTS TIRE COMPANY              1           1      111
# C0606683 - JAMAR TIRE SERVICE                        1           1      111
# C0606027 - STALEY'S TIRE & AUTOMOTIVE                1           1      111
# C0005108 - TIRESOLES/ELPEX-FT. PIERCE                1           1      111
# C0051334 - STRATHAM TIRE                             1           1      111
# C0008752 - TIRE OUTLET, INC.                         1           1      111
# C0029352 - FLEET TIRE SERVICE, INC.                  1           1      111
# C0009022 - GENE'S TIRES INC.                         1           1      111
# C0008915 - TRIPLE T AUTOMOTIVE, LLC                  1           1      111
# C0009059 - GOOD TIRE                                 1           1      111
# C0008047 - ROADRUNNER TIRE DISTRUBUTORS              1           1      111
# C0606740 - HARRY VANCE LOGGING                       1           1      111
# C0025204 - BILLINGSLEY TIRE                          1           1      111
# C0601770 - ROY'S TIRES, INC                          1           1      111
# C0009105 - BOB SUMEREL TIRE COMPANY, INC.            1           1      111
# C0001074 - REDDING VALLEY TIRE INC                   1           1      111
# C0083625 - HEUTON TIRE COMPANY                       1           1      111
# C0700082 - VALLEY TIRE SALES                         1           1      111
# C0045412 - D & J TIRE INC                            1           1      111
# C0050754 - HERMAN POWER TIRE SVC., INC.              1           1      111
# C0007974 - BINGHAMTON TRUCK & TIRE CENTER            1           1      111
# C0600734 - CROSS DILLON TIRE, INC.                   1           1      111
# C0606823 - DISCOUNT TRUCK TIRES, LLC                 1           1      111
# C0009612 - HIGHWAY TIRE, INC.                        1           1      111

# %%
# How many customers we have in each segments
print("Best Customers: ",len(segmented_rfm[segmented_rfm['RFMScore']=='111']))
print('Loyal Customers: ',len(segmented_rfm[segmented_rfm['f_quartile']==1]))
print("Big Spenders: ",len(segmented_rfm[segmented_rfm['m_quartile']==1]))
print('Almost Lost: ', len(segmented_rfm[segmented_rfm['RFMScore']=='211']))
print('Lost Customers: ',len(segmented_rfm[segmented_rfm['RFMScore']=='411']))
print('Lost Cheap Customers: ',len(segmented_rfm[segmented_rfm['RFMScore']=='444']))
# Out:
# Best Customers:  171
# Loyal Customers:  547
# Big Spenders:  547
# Almost Lost:  159
# Lost Customers:  17
# Lost Cheap Customers:  238

# %%
#write the result to excel file
writer = pd.ExcelWriter('rfm_score.xlsx', engine = 'xlsxwriter')

segmented_rfm.sort_values(by = ['RFMScore','Monetary_Value'], ascending=[True, False]).to_excel(writer,'Sheet1')

writer.save()

# %%
#count members in each segment
segmented_rfm["RFMScore"].value_counts().plot(kind = 'bar', figsize = (12,4))

# %% [markdown]
# ## Customer Basket Size Analysis

# %%
#build k-means clustering model
#look at dataset again
data_stat = sales_us_am.describe()
data_stat
# Out:
#                 Year       Quantity        X Sales            ASP
# count  453006.000000  453006.000000  453006.000000  453006.000000
# mean     2015.844406       8.436211    2310.297423     432.610951
# std         1.378762      17.713731    3910.776763     553.816270
# min      2014.000000       1.000000       1.000000       0.877143
# 25%      2015.000000       2.000000     515.685000     170.230000
# 50%      2016.000000       4.000000    1144.640000     221.230000
# 75%      2017.000000       8.000000    2500.297500     414.852500
# max      2018.000000     800.000000  167929.980000   54052.000000

# %%
#explore basket size
sales_order = sales_us_am.groupby(by=['Customer','Invoice No.']).agg({'X Sales': lambda x: x.sum()})

# %%
sales_order['X Sales'].min()
# Out:
# 24.54

# %%
sales_range = [0, 1000, 3000, 7000, 15000, 30000, 50000]
count_price = []
for i, price in enumerate(sales_range):
    if i == 0: continue
    val = sales_order[(sales_order['X Sales'] < price) &
                       (sales_order['X Sales'] > sales_range[i-1])]['X Sales'].count()
    count_price.append(val)
# draw pie chart        
plt.rc('font', weight='bold')
f, ax = plt.subplots(figsize=(11, 6))
colors = ['yellowgreen', 'gold', 'wheat', 'c', 'violet', 'royalblue','firebrick']
labels = [ '{}<.<{}'.format(sales_range[i-1], s) for i,s in enumerate(sales_range) if i != 0]
sizes  = count_price
explode = [0.0 if sizes[i] < 100 else 0.0 for i in range(len(sizes))]
ax.pie(sizes, explode = explode, labels=labels, colors = colors,
       autopct = lambda x:'{:1.0f}%'.format(x) if x > 1 else '',
       shadow = False, startangle=0)
ax.axis('equal')
f.text(0.5, 1.01, "Order Size", ha='center', fontsize = 18);

# %% [markdown]
# ## Clustering Modeling by Category and Channel

# %% [markdown]
# Find customer annual spending in each category and channel(geo location?) only look at recent 3 years

# %%
cat_temp_table = sales_us_am.loc[sales_us_am['Year']>2015,:].groupby(['Customer','Final Category', 'Channel']).agg({'X Sales': lambda x: x.sum()})

# %%
cat_temp_table.head(10)
# Out:
#                                                               X Sales
# Customer                          Final Category  Channel
# 010130 - AAL-STAR TIRE            Radial OTR      WAREHOUSE  14371.68
# 0101570 - J & O TIRE              Bias OTR        WAREHOUSE  33459.60
#                                   CU              WAREHOUSE   8711.32
#                                   IND             WAREHOUSE   7079.87
#                                   SS              WAREHOUSE   4348.24
#                                   Truck           WAREHOUSE  12698.00
# 01070 - ALLIED OIL & SUPPLY, INC. Trailer Service WAREHOUSE   3300.00
# 01074 - REDDING VALLEY TIRE INC   AGR             WAREHOUSE   4152.00
#                                   Bias OTR        WAREHOUSE  35941.96
#                                   CU              WAREHOUSE  17246.35

# %%
#spread category
cat_table = cat_temp_table.pivot_table(index = ['Customer','Channel'], columns = 'Final Category', values = 'X Sales')

# %%
#reset index to columns
cat_table.reset_index(inplace = True)

# %%
#impute na as 0
cat_table.fillna(0, inplace = True)

# %%
#encoding channel by using getDummy fun in PD
from sklearn.preprocessing import LabelBinarizer

# %%
cat_table_final = pd.get_dummies(cat_table, columns = ['Channel'])

# %%
#viz the feature distribution
pd.plotting.scatter_matrix(cat_table_final, alpha = 0.3, figsize = (16,16), diagonal = 'kde');

# %%
#set customer as index
cat_table_final.set_index('Customer', inplace = True)

# %%
#get correlation scores
cat_table_final.corr()
# Out:
#                         AGR  Bias OTR        CU       FOR       IND        LG  \
# AGR                1.000000  0.367226  0.389519  0.227721  0.227925  0.295235
# Bias OTR           0.367226  1.000000  0.686185  0.709983  0.719622  0.476206
# CU                 0.389519  0.686185  1.000000  0.525783  0.775114  0.442869
# FOR                0.227721  0.709983  0.525783  1.000000  0.598126  0.385875
# IND                0.227925  0.719622  0.775114  0.598126  1.000000  0.436624
# LG                 0.295235  0.476206  0.442869  0.385875  0.436624  1.000000
# OTHER              0.092562  0.002351  0.020852 -0.000058 -0.000854  0.019394
# Radial OTR         0.187481  0.624816  0.588905  0.615283  0.580026  0.368352
# SOLID              0.090297  0.294366  0.228510  0.246900  0.235528  0.258927
# SS                 0.392768  0.531132  0.734751  0.413668  0.543520  0.527948
# Trailer Service    0.173616  0.389120  0.483680  0.432461  0.483951  0.346359
# Truck              0.149899  0.257024  0.250750  0.318117  0.255303  0.152706
# Channel_CONTAINER  0.231279  0.011195  0.148794  0.023424  0.031675 -0.037832
# Channel_WAREHOUSE -0.231279 -0.011195 -0.148794 -0.023424 -0.031675  0.037832
#
#                       OTHER  Radial OTR     SOLID        SS  Trailer Service  \
# AGR                0.092562    0.187481  0.090297  0.392768         0.173616
# Bias OTR           0.002351    0.624816  0.294366  0.531132         0.389120
# CU                 0.020852    0.588905  0.228510  0.734751         0.483680
# FOR               -0.000058    0.615283  0.246900  0.413668         0.432461
# IND               -0.000854    0.580026  0.235528  0.543520         0.483951
# LG                 0.019394    0.368352  0.258927  0.527948         0.346359
# OTHER              1.000000    0.018152  0.013486  0.154785        -0.000391
# Radial OTR         0.018152    1.000000  0.330732  0.490555         0.463356
# SOLID              0.013486    0.330732  1.000000  0.298077         0.195188
# SS                 0.154785    0.490555  0.298077  1.000000         0.441034
# Trailer Service   -0.000391    0.463356  0.195188  0.441034         1.000000
# Truck              0.043941    0.346732  0.208687  0.306774         0.213091
# Channel_CONTAINER  0.040990   -0.061569 -0.002773  0.148365        -0.031944
# Channel_WAREHOUSE -0.040990    0.061569  0.002773 -0.148365         0.031944
#
#                       Truck  Channel_CONTAINER  Channel_WAREHOUSE
# AGR                0.149899           0.231279          -0.231279
# Bias OTR           0.257024           0.011195          -0.011195
# CU                 0.250750           0.148794          -0.148794
# FOR                0.318117           0.023424          -0.023424
# IND                0.255303           0.031675          -0.031675
# LG                 0.152706          -0.037832           0.037832
# OTHER              0.043941           0.040990          -0.040990
# Radial OTR         0.346732          -0.061569           0.061569
# SOLID              0.208687          -0.002773           0.002773
# SS                 0.306774           0.148365          -0.148365
# Trailer Service    0.213091          -0.031944           0.031944
# Truck              1.000000           0.063740          -0.063740
# Channel_CONTAINER  0.063740           1.000000          -1.000000
# Channel_WAREHOUSE -0.063740          -1.000000           1.000000

# %% [markdown]
# ## Clustering

# %%
#find the best clusters by apply the silhouette score
matrix = cat_table_final.copy().drop(['Channel_CONTAINER','Channel_WAREHOUSE'], axis =1).values
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.9289209674158396
# For n_clusters = 3 The average silhouette_score is : 0.8806374368846344
# For n_clusters = 4 The average silhouette_score is : 0.8600322254342155
# For n_clusters = 5 The average silhouette_score is : 0.8643922522846073
# For n_clusters = 6 The average silhouette_score is : 0.7602620529029975
# For n_clusters = 7 The average silhouette_score is : 0.810346911056969
# For n_clusters = 8 The average silhouette_score is : 0.7353916853720254
# For n_clusters = 9 The average silhouette_score is : 0.7297406288902561

# %%
##standardized the data set
scaler = StandardScaler()
scaler.fit(matrix)
print('variables mean values: \n' + 90*'-' + '\n' , scaler.mean_)
scaled_matrix = scaler.transform(matrix)
# Out:
# variables mean values:
# ------------------------------------------------------------------------------------------
#  [89404.90942693 15210.93523878 25519.73563992 32198.30938395
#   4036.03126074  2229.19323305    95.81758835 20153.56675263
#   2973.89793696 27199.1743362   2830.35788921 73422.23189589]

# %% [markdown]
# ### PCA

# %%
pca = PCA()
pca.fit(scaled_matrix)
pca_samples = pca.transform(scaled_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-b8396669cd32> in <module>()
# ----> 1 pca = PCA()
#       2 pca.fit(scaled_matrix)
#       3 pca_samples = pca.transform(scaled_matrix)
#
# NameError: name 'PCA' is not defined

# %%
for n_clusters in range(2,10):
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=30)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

# %%
n_clusters = 5
silhouette_avg = -1
while silhouette_avg < 0.145:
    kmeans = KMeans(init='k-means++', n_clusters = n_clusters, n_init=30)
    kmeans.fit(matrix)
    clusters = kmeans.predict(matrix)
    silhouette_avg = silhouette_score(matrix, clusters)
    
    #km = kmodes.KModes(n_clusters = n_clusters, init='Huang', n_init=2, verbose=0)
    #clusters = km.fit_predict(matrix)
    #silhouette_avg = silhouette_score(matrix, clusters)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 5 The average silhouette_score is : 0.8596161964108419

# %%
def graph_component_silhouette(n_clusters, lim_x, mat_size, sample_silhouette_values, clusters):
    plt.rcParams["patch.force_edgecolor"] = True
    plt.style.use('fivethirtyeight')
    mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
    #____________________________
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(8, 16)
    ax1.set_xlim([lim_x[0], lim_x[1]])
    ax1.set_ylim([0, mat_size + (n_clusters + 1) * 10])
    y_lower = 10
    for i in range(n_clusters):
        #___________________________________________________________________________________
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[clusters == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        cmap = cm.get_cmap("Spectral")
        color = cmap(float(i) / n_clusters)        
        ax1.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values,
                           facecolor=color, edgecolor=color, alpha=0.8)
        #____________________________________________________________________
        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.03, y_lower + 0.5 * size_cluster_i, str(i), color = 'red', fontweight = 'bold',
                bbox=dict(facecolor='white', edgecolor='black', boxstyle='round, pad=0.3'))
        #______________________________________
        # Compute the new y_lower for next plot
        y_lower = y_upper + 10

# %%
sample_silhouette_values = silhouette_samples(matrix, clusters)

graph_component_silhouette(n_clusters, [-0.07, 0.9], len(cat_table_final.copy().drop(['Channel_CONTAINER','Channel_WAREHOUSE'], axis =1)), sample_silhouette_values, clusters)
